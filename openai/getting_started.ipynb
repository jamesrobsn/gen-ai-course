# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
# Langsmith Tracking
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(
    model="gpt-4.1-mini"
)
print(llm)
# Out:
# client=<openai.resources.chat.completions.completions.Completions object at 0x000001B4AB017B50> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001B4AB50F2D0> root_client=<openai.OpenAI object at 0x000001B4AB0A3290> root_async_client=<openai.AsyncOpenAI object at 0x000001B4AB50EDD0> model_name='gpt-4.1-mini' temperature=0.0 model_kwargs={} openai_api_key=SecretStr('**********')

# %%
## Input and get response
result = llm.invoke("What is generative AI?")

# %%
print(result)
# Out:
# content='Generative AI refers to a category of artificial intelligence systems designed to create new content, such as text, images, music, or code, that resembles data they were trained on. Unlike traditional AI, which might classify or analyze existing data, generative AI models learn patterns from large datasets and use that knowledge to generate original outputs.\n\nExamples of generative AI include:\n\n- **Text generation:** Models like GPT (Generative Pre-trained Transformer) that can write essays, answer questions, or create stories.\n- **Image generation:** Systems like DALL·E or Stable Diffusion that produce images from textual descriptions.\n- **Music and audio generation:** AI that composes music or synthesizes human-like speech.\n\nGenerative AI is widely used in creative industries, content creation, design, and even software development, enabling new forms of human-computer interaction and automation.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 172, 'prompt_tokens': 13, 'total_tokens': 185, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': None, 'id': 'chatcmpl-BvmtQWvkAsfwEXdATXB54gYvqP5qp', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--d642850f-e6fd-4ee5-9e65-c5fbc6c8d300-0' usage_metadata={'input_tokens': 13, 'output_tokens': 172, 'total_tokens': 185, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
### Chatprompt template
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an expert AI Engineer. Provide me answers based on the question."),
    ("user", "{input}")
])

prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answers based on the question.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain = prompt | llm
result = chain.invoke({"input": "Can you tell me about Langsmith?"})
print(result)
# Out:
# content='Langsmith is a platform developed by LangChain designed to help developers build, debug, and manage applications powered by large language models (LLMs). It provides tools and infrastructure to track, visualize, and optimize the execution of language model chains and agents, making it easier to develop complex AI workflows.\n\nKey features of Langsmith include:\n\n- **Execution Tracking:** Automatically logs inputs, outputs, and intermediate steps of LLM chains and agents for better observability.\n- **Visualization:** Offers a user-friendly interface to visualize the flow and decision-making process of language model applications.\n- **Debugging Tools:** Helps identify issues and optimize prompts or chain logic by inspecting detailed execution traces.\n- **Collaboration:** Enables teams to share and review language model workflows and results.\n- **Integration:** Seamlessly integrates with LangChain, enhancing the development experience for LLM-based applications.\n\nOverall, Langsmith aims to streamline the development lifecycle of AI applications that leverage large language models by providing transparency, control, and collaboration capabilities.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 200, 'prompt_tokens': 34, 'total_tokens': 234, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': None, 'id': 'chatcmpl-BvmzQhw13wC7D9eHdMn4xfdZhRoE4', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--aef58c2e-3a8a-4e07-8f91-bff9a6c262b8-0' usage_metadata={'input_tokens': 34, 'output_tokens': 200, 'total_tokens': 234, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
type(result)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
## stroutput praser
from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()
chain = prompt | llm | output_parser
result = chain.invoke({"input": "Can you tell me about Langsmith?"})
print(result)
# Out:
# Langsmith is a platform developed by LangChain designed to help developers build, debug, and manage applications powered by large language models (LLMs). It provides tools and infrastructure to track the execution of LLM calls, visualize workflows, and analyze the behavior of language model applications. With Langsmith, developers can gain insights into how their prompts and chains perform, identify bottlenecks or errors, and optimize their applications for better results. It essentially acts as a comprehensive toolkit for developing and maintaining robust LLM-powered solutions.
